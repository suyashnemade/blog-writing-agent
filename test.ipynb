# %%
from blogwriter.workflow import app


app

# %%
from blogwriter.workflow import app


app

# %%
from blogwriter.agents.reducer import reducer_subgraph

reducer_subgraph
